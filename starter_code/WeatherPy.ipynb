# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL 
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Create a list to hold the weather data
city_data = []

# build query URL
query_url = f"{url}appid={weather_api_key}&units=imperial&q="
print(query_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?appid=6b8d8ead20a6d272e0251c3389660b71&units=imperial&q=

# %%
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,})

    # If an error is experienced, skip the city
    except:
        print(city + " not found. Skipping...")
        pass

    record_count = record_count + 1

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vernouillet
# Processing Record 3 of Set 1 | qaqortoq
# Processing Record 5 of Set 1 | badger
# Processing Record 7 of Set 1 | waitangi
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | sharm el-sheikh
# Processing Record 13 of Set 1 | bardai
# Processing Record 15 of Set 1 | saipan
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | holualoa
# Processing Record 21 of Set 1 | enewetak
# Processing Record 23 of Set 1 | college
# Processing Record 25 of Set 1 | tampere
# Processing Record 27 of Set 1 | sanguesa/zangoza
# sanguesa/zangoza not found. Skipping...
# Processing Record 29 of Set 1 | prince rupert
# Processing Record 31 of Set 1 | invercargill
# Processing Record 33 of Set 1 | adamstown
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | vila do maio
# Processing Record 39 of Set 1 | shache
# Processing Record 41 of Set 1 | alotau
# Processing Record 43 of Set 1 | as sulayyil
# Processing Record 45 of Set 1 | saint-pierre
# Processing Record 47 of Set 1 | thompson
# Processing Record 49 of Set 1 | aleksandrovsk-sakhalinskiy
# Processing Record 51 of Set 1 | port mathurin
# Processing Record 53 of Set 1 | hajin
# Processing Record 55 of Set 1 | olyokminsk
# Processing Record 57 of Set 1 | flying fish cove
# Processing Record 59 of Set 1 | lamar
# Processing Record 61 of Set 1 | ketchikan
# Processing Record 63 of Set 1 | teploye
# Processing Record 65 of Set 1 | papatowai
# Processing Record 67 of Set 1 | hamilton
# Processing Record 69 of Set 1 | boyolangu
# Processing Record 71 of Set 1 | la ronge
# Processing Record 73 of Set 1 | albany
# Processing Record 75 of Set 1 | bikenibeu village
# Processing Record 77 of Set 1 | kingston
# Processing Record 79 of Set 1 | iqaluit
# Processing Record 81 of Set 1 | suva
# Processing Record 83 of Set 1 | taiohae
# taiohae not found. Skipping...
# Processing Record 85 of Set 1 | serra san bruno
# Processing Record 87 of Set 1 | vingt cinq
# vingt cinq not found. Skipping...
# Processing Record 89 of Set 1 | piti village
# Processing Record 91 of Set 1 | lompoc
# Processing Record 93 of Set 1 | paharpur
# Processing Record 95 of Set 1 | port-aux-francais
# Processing Record 97 of Set 1 | olonkinbyen
# Processing Record 99 of Set 1 | petrozavodsk
# Processing Record 0 of Set 2 | kosonsoy
# Processing Record 2 of Set 2 | kodiak
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | anadyr
# Processing Record 10 of Set 2 | chandbali
# Processing Record 12 of Set 2 | tidjikja
# Processing Record 14 of Set 2 | sagarejo
# Processing Record 16 of Set 2 | axim
# Processing Record 18 of Set 2 | hammerfest
# Processing Record 20 of Set 2 | talara
# Processing Record 22 of Set 2 | miles city
# Processing Record 24 of Set 2 | avarua
# Processing Record 26 of Set 2 | callaway
# Processing Record 28 of Set 2 | kone
# Processing Record 30 of Set 2 | puerto natales
# Processing Record 32 of Set 2 | bodaybo
# Processing Record 34 of Set 2 | tateyama
# Processing Record 36 of Set 2 | grytviken
# Processing Record 38 of Set 2 | lihue
# Processing Record 40 of Set 2 | mocimboa
# Processing Record 42 of Set 2 | torre del lago puccini
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | georgetown
# Processing Record 48 of Set 2 | al ghayzah
# Processing Record 50 of Set 2 | pisco
# Processing Record 52 of Set 2 | post
# Processing Record 54 of Set 2 | serres
# Processing Record 56 of Set 2 | talnakh
# Processing Record 58 of Set 2 | babu
# Processing Record 60 of Set 2 | necochea
# Processing Record 62 of Set 2 | bilibino
# Processing Record 64 of Set 2 | yellowknife
# Processing Record 66 of Set 2 | ilulissat
# Processing Record 68 of Set 2 | ola
# Processing Record 70 of Set 2 | prince george
# Processing Record 72 of Set 2 | heroica caborca
# Processing Record 74 of Set 2 | tazovsky
# Processing Record 76 of Set 2 | blackmans bay
# Processing Record 78 of Set 2 | vorgashor
# Processing Record 80 of Set 2 | port elizabeth
# Processing Record 82 of Set 2 | quartu sant'elena
# Processing Record 84 of Set 2 | kirs
# Processing Record 86 of Set 2 | changji
# Processing Record 88 of Set 2 | kiffa
# Processing Record 90 of Set 2 | perambalur
# Processing Record 92 of Set 2 | ust-nera
# Processing Record 94 of Set 2 | oyem
# Processing Record 96 of Set 2 | chonchi
# Processing Record 98 of Set 2 | aquin
# Processing Record 0 of Set 3 | ceerigaabo
# Processing Record 2 of Set 3 | moultonborough
# Processing Record 4 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 3 | gunsan
# Processing Record 8 of Set 3 | sitka
# Processing Record 10 of Set 3 | tromso
# Processing Record 12 of Set 3 | thunder bay
# Processing Record 14 of Set 3 | happy valley-goose bay
# Processing Record 16 of Set 3 | ormara
# Processing Record 18 of Set 3 | san bernardo del viento
# Processing Record 20 of Set 3 | matoury
# Processing Record 22 of Set 3 | kerikeri
# Processing Record 24 of Set 3 | rovaniemi
# Processing Record 26 of Set 3 | jamestown
# Processing Record 28 of Set 3 | trairi
# Processing Record 30 of Set 3 | remire-montjoly
# Processing Record 32 of Set 3 | tamanrasset
# Processing Record 34 of Set 3 | huambo
# Processing Record 36 of Set 3 | kiunga
# Processing Record 38 of Set 3 | machico
# Processing Record 40 of Set 3 | nemuro
# Processing Record 42 of Set 3 | cidreira
# Processing Record 44 of Set 3 | ndjole
# Processing Record 46 of Set 3 | elmendorf air force base
# elmendorf air force base not found. Skipping...
# Processing Record 48 of Set 3 | cubulco
# Processing Record 50 of Set 3 | bethel
# Processing Record 52 of Set 3 | ejido benito juarez
# ejido benito juarez not found. Skipping...
# Processing Record 54 of Set 3 | west island
# Processing Record 56 of Set 3 | constantia
# Processing Record 58 of Set 3 | tumpat
# Processing Record 60 of Set 3 | thames
# Processing Record 62 of Set 3 | paracuru
# Processing Record 64 of Set 3 | cabo san lucas
# Processing Record 66 of Set 3 | beruniy
# Processing Record 68 of Set 3 | laayoune plage
# laayoune plage not found. Skipping...
# Processing Record 70 of Set 3 | berdigestyakh
# Processing Record 72 of Set 3 | faya-largeau
# Processing Record 74 of Set 3 | afaahiti
# Processing Record 76 of Set 3 | ko pha ngan
# Processing Record 78 of Set 3 | howard springs
# Processing Record 80 of Set 3 | amga
# Processing Record 82 of Set 3 | dawson creek
# Processing Record 84 of Set 3 | loanda
# Processing Record 86 of Set 3 | al fuwayliq
# Processing Record 88 of Set 3 | nagqu
# Processing Record 90 of Set 3 | namtsy
# Processing Record 92 of Set 3 | serowe
# Processing Record 94 of Set 3 | dakhla
# Processing Record 96 of Set 3 | key largo
# Processing Record 98 of Set 3 | nar'yan-mar
# Processing Record 0 of Set 4 | tura
# Processing Record 2 of Set 4 | dunedin
# Processing Record 4 of Set 4 | northam
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | san patricio
# Processing Record 10 of Set 4 | xilin hot
# Processing Record 12 of Set 4 | sao geraldo do araguaia
# Processing Record 14 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | idri
# Processing Record 18 of Set 4 | zaozersk
# Processing Record 20 of Set 4 | revda
# Processing Record 22 of Set 4 | fortuna
# Processing Record 24 of Set 4 | vilyuchinsk
# Processing Record 26 of Set 4 | luderitz
# Processing Record 28 of Set 4 | zaragoza
# Processing Record 30 of Set 4 | klyuchi
# Processing Record 32 of Set 4 | cargados carajos
# cargados carajos not found. Skipping...
# Processing Record 34 of Set 4 | fuvahmulah
# fuvahmulah not found. Skipping...
# Processing Record 36 of Set 4 | east london
# Processing Record 38 of Set 4 | saint-francois
# Processing Record 40 of Set 4 | cooma
# Processing Record 42 of Set 4 | key west
# Processing Record 44 of Set 4 | toamasina
# Processing Record 46 of Set 4 | breaux bridge
# Processing Record 48 of Set 4 | rio grande
# Processing Record 50 of Set 4 | margaret river
# Processing Record 52 of Set 4 | carutapera
# Processing Record 54 of Set 4 | qarah bagh
# Processing Record 56 of Set 4 | filadelfia
# Processing Record 58 of Set 4 | stanley
# Processing Record 60 of Set 4 | huarmey
# Processing Record 62 of Set 4 | muravlenko
# Processing Record 64 of Set 4 | vadso
# Processing Record 66 of Set 4 | hawaiian paradise park
# Processing Record 68 of Set 4 | puerto carreno
# Processing Record 70 of Set 4 | tiksi
# Processing Record 72 of Set 4 | crane
# Processing Record 74 of Set 4 | san luis de la loma
# Processing Record 76 of Set 4 | uturoa
# Processing Record 78 of Set 4 | lebu
# Processing Record 80 of Set 4 | mohale's hoek
# Processing Record 82 of Set 4 | qarazhal
# Processing Record 84 of Set 4 | la punta
# Processing Record 86 of Set 4 | isafjordur
# Processing Record 88 of Set 4 | yunyang
# Processing Record 90 of Set 4 | daru
# Processing Record 92 of Set 4 | wajir
# Processing Record 94 of Set 4 | coruripe
# Processing Record 96 of Set 4 | badulla
# Processing Record 98 of Set 4 | fort bragg
# Processing Record 0 of Set 5 | vuktyl
# Processing Record 2 of Set 5 | ubari
# Processing Record 4 of Set 5 | rongelap
# Processing Record 6 of Set 5 | taroa
# Processing Record 8 of Set 5 | kampene
# Processing Record 10 of Set 5 | urengoy
# Processing Record 12 of Set 5 | queenstown
# Processing Record 14 of Set 5 | sukumo
# Processing Record 16 of Set 5 | weno
# Processing Record 18 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | new yekepa
# Processing Record 22 of Set 5 | esmeraldas
# Processing Record 24 of Set 5 | kirensk
# Processing Record 26 of Set 5 | nadi
# Processing Record 28 of Set 5 | mairwa
# Processing Record 30 of Set 5 | st. john's
# Processing Record 32 of Set 5 | ivdel'
# Processing Record 34 of Set 5 | southside
# Processing Record 36 of Set 5 | colonia
# Processing Record 38 of Set 5 | dongtai
# Processing Record 40 of Set 5 | iranshahr
# Processing Record 42 of Set 5 | udachny
# Processing Record 44 of Set 5 | belmonte
# Processing Record 46 of Set 5 | tazacorte
# Processing Record 48 of Set 5 | jaslo
# Processing Record 50 of Set 5 | kapit
# Processing Record 52 of Set 5 | qamdo
# Processing Record 54 of Set 5 | puerto san carlos
# puerto san carlos not found. Skipping...
# Processing Record 56 of Set 5 | vernon
# Processing Record 58 of Set 5 | luau
# Processing Record 60 of Set 5 | hauterive
# Processing Record 62 of Set 5 | crookston
# Processing Record 64 of Set 5 | pecos
# Processing Record 66 of Set 5 | mili
# Processing Record 68 of Set 5 | bereznik
# Processing Record 70 of Set 5 | noumea
# Processing Record 72 of Set 5 | pontevedra
# Processing Record 74 of Set 5 | cairns city
# cairns city not found. Skipping...
# Processing Record 76 of Set 5 | champerico
# Processing Record 78 of Set 5 | thinadhoo
# Processing Record 80 of Set 5 | mandalgovi
# Processing Record 82 of Set 5 | levuka
# Processing Record 84 of Set 5 | severo-yeniseyskiy
# Processing Record 86 of Set 5 | port alfred
# Processing Record 88 of Set 5 | callao
# Processing Record 90 of Set 5 | sola
# Processing Record 92 of Set 5 | keflavik
# Processing Record 94 of Set 5 | naze
# Processing Record 96 of Set 5 | salalah
# Processing Record 98 of Set 5 | polyarnyy
# Processing Record 0 of Set 6 | arkhangel'sk
# Processing Record 2 of Set 6 | kodinsk
# Processing Record 4 of Set 6 | ballina
# Processing Record 6 of Set 6 | saudarkrokur
# Processing Record 8 of Set 6 | tolanaro
# Processing Record 10 of Set 6 | pechora
# Processing Record 12 of Set 6 | pandharpur
# Processing Record 14 of Set 6 | yatou
# Processing Record 16 of Set 6 | kavieng
# Processing Record 18 of Set 6 | nogliki
# Processing Record 20 of Set 6 | alice springs
# Processing Record 22 of Set 6 | tomatlan
# Processing Record 24 of Set 6 | hinton
# Processing Record 26 of Set 6 | kudahuvadhoo
# Processing Record 28 of Set 6 | aasiaat
# Processing Record 30 of Set 6 | san antonio del estrecho
# san antonio del estrecho not found. Skipping...
# Processing Record 32 of Set 6 | cabugao
# Processing Record 34 of Set 6 | caspe
# Processing Record 36 of Set 6 | menongue
# Processing Record 38 of Set 6 | retreat
# Processing Record 40 of Set 6 | vrangel'
# Processing Record 42 of Set 6 | gjakove
# gjakove not found. Skipping...
# Processing Record 44 of Set 6 | inirida
# Processing Record 46 of Set 6 | codrington
# Processing Record 48 of Set 6 | dazhong
# Processing Record 50 of Set 6 | farafangana
# Processing Record 52 of Set 6 | svetlyy
# Processing Record 54 of Set 6 | campbell river
# Processing Record 56 of Set 6 | vecindario
# vecindario not found. Skipping...
# Processing Record 58 of Set 6 | hereford
# Processing Record 60 of Set 6 | yaren
# Processing Record 62 of Set 6 | mount isa
# Processing Record 64 of Set 6 | fuzhou
# Processing Record 66 of Set 6 | mount pearl
# Processing Record 68 of Set 6 | barranca
# Processing Record 70 of Set 6 | auki
# Processing Record 72 of Set 6 | ciudad lazaro cardenas
# Processing Record 74 of Set 6 | baturaja
# Processing Record 76 of Set 6 | xacmaz
# Processing Record 78 of Set 6 | papao
# Processing Record 80 of Set 6 | punta arenas
# Processing Record 82 of Set 6 | calabozo
# Processing Record 84 of Set 6 | tomobe
# Processing Record 86 of Set 6 | jalqani
# Processing Record 88 of Set 6 | prieska
# Processing Record 90 of Set 6 | kailua-kona
# Processing Record 92 of Set 6 | puerto baquerizo moreno
# Processing Record 94 of Set 6 | vorkuta
# Processing Record 96 of Set 6 | whistler
# Processing Record 98 of Set 6 | khilok
# Processing Record 0 of Set 7 | tokar
# Processing Record 2 of Set 7 | wailua homesteads
# Processing Record 4 of Set 7 | hasaki
# Processing Record 6 of Set 7 | guaraciaba do norte
# Processing Record 8 of Set 7 | asau village
# asau village not found. Skipping...
# Processing Record 10 of Set 7 | ladang seri kundang
# Processing Record 12 of Set 7 | kasongo-lunda
# Processing Record 14 of Set 7 | ancud
# Processing Record 16 of Set 7 | aroma
# Processing Record 18 of Set 7 | sapulpa
# Processing Record 20 of Set 7 | bongaree
# Processing Record 22 of Set 7 | djibouti
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 26 of Set 7 | mahibadhoo
# Processing Record 28 of Set 7 | floro
# Processing Record 30 of Set 7 | sechura
# Processing Record 32 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | flin flon
# Processing Record 36 of Set 7 | dhidhdhoo
# Processing Record 38 of Set 7 | kargopol'
# Processing Record 40 of Set 7 | cumaribo
# cumaribo not found. Skipping...
# Processing Record 42 of Set 7 | ba
# ba not found. Skipping...
# Processing Record 44 of Set 7 | sucua
# Processing Record 46 of Set 7 | dudinka
# Processing Record 48 of Set 7 | burela de cabo
# Processing Record 50 of Set 7 | kerman
# Processing Record 52 of Set 7 | khandyga
# Processing Record 54 of Set 7 | hobyo
# Processing Record 56 of Set 7 | mil'kovo
# Processing Record 58 of Set 7 | greater sudbury
# Processing Record 60 of Set 7 | fale old settlement
# Processing Record 62 of Set 7 | iskateley
# Processing Record 64 of Set 7 | chui
# Processing Record 66 of Set 7 | oriximina
# Processing Record 68 of Set 7 | porto novo
# Processing Record 70 of Set 7 | daxi
# Processing Record 72 of Set 7 | mount gambier
# Processing Record 74 of Set 7 | kokstad
# Processing Record 76 of Set 7 | whakatane
# Processing Record 78 of Set 7 | okhotsk
# Processing Record 80 of Set 7 | fort mcmurray
# Processing Record 82 of Set 7 | sumbawa besar
# Processing Record 84 of Set 7 | jincheng
# Processing Record 86 of Set 7 | kankanhalli
# Processing Record 88 of Set 7 | nha trang
# Processing Record 90 of Set 7 | presidente epitacio
# Processing Record 92 of Set 7 | sittwe
# Processing Record 94 of Set 7 | 'ohonua
# 'ohonua not found. Skipping...
# Processing Record 96 of Set 7 | pader
# Processing Record 98 of Set 7 | arcadia
# Processing Record 0 of Set 8 | belyy yar
# Processing Record 2 of Set 8 | fujin
# Processing Record 4 of Set 8 | grantsville
# Processing Record 6 of Set 8 | alo
# Processing Record 8 of Set 8 | crieff
# Processing Record 10 of Set 8 | tual
# Processing Record 12 of Set 8 | san fernando de monte cristi
# Processing Record 14 of Set 8 | nuuk
# Processing Record 16 of Set 8 | dunhua
# Processing Record 18 of Set 8 | lodja
# Processing Record 20 of Set 8 | hilo
# Processing Record 22 of Set 8 | envira
# Processing Record 24 of Set 8 | kingscliff
# Processing Record 26 of Set 8 | thurgoona
# Processing Record 28 of Set 8 | lakeland highlands
# Processing Record 30 of Set 8 | kununurra
# Processing Record 32 of Set 8 | farasan
# Processing Record 34 of Set 8 | takedamachi
# Processing Record 36 of Set 8 | dosso
# Processing Record 38 of Set 8 | myrina
# Processing Record 40 of Set 8 | yakeshi
# Processing Record 42 of Set 8 | sault ste. marie
# Processing Record 44 of Set 8 | nanawua
# Processing Record 46 of Set 8 | broken hill
# Processing Record 48 of Set 8 | nizip
# Processing Record 50 of Set 8 | cockburn town
# Processing Record 52 of Set 8 | turaif
# Processing Record 54 of Set 8 | diebougou
# Processing Record 56 of Set 8 | laguna
# Processing Record 58 of Set 8 | siwa oasis
# Processing Record 60 of Set 8 | mahina
# Processing Record 62 of Set 8 | santo andre
# Processing Record 64 of Set 8 | prado
# Processing Record 66 of Set 8 | cefalu
# Processing Record 68 of Set 8 | aginskoye
# Processing Record 70 of Set 8 | rawson
# Processing Record 72 of Set 8 | bargersville
# Processing Record 74 of Set 8 | ta`u
# Processing Record 76 of Set 8 | ytyk-kyuyel'
# ytyk-kyuyel' not found. Skipping...
# Processing Record 78 of Set 8 | new norfolk
# Processing Record 80 of Set 8 | gongdanglegi kulon
# Processing Record 82 of Set 8 | brisas de zicatela
# Processing Record 84 of Set 8 | atafu village
# Processing Record 86 of Set 8 | inhambane
# Processing Record 88 of Set 8 | phan thiet
# Processing Record 90 of Set 8 | tshabong
# Processing Record 92 of Set 8 | kuala terengganu
# Processing Record 94 of Set 8 | emerald
# Processing Record 96 of Set 8 | krylovskaya
# Processing Record 98 of Set 8 | smithers
# Processing Record 0 of Set 9 | edd
# Processing Record 2 of Set 9 | chicxulub puerto
# chicxulub puerto not found. Skipping...
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | madang
# Processing Record 8 of Set 9 | kitimat
# Processing Record 10 of Set 9 | tsiombe
# Processing Record 12 of Set 9 | caconda
# Processing Record 14 of Set 9 | jian'ou
# Processing Record 16 of Set 9 | hermanus
# Processing Record 18 of Set 9 | pizarro
# Processing Record 20 of Set 9 | stanthorpe
# Processing Record 22 of Set 9 | khanjarah
# Processing Record 24 of Set 9 | carinhanha
# Processing Record 26 of Set 9 | kingaroy
# Processing Record 28 of Set 9 | la passe
# Processing Record 30 of Set 9 | hayma'
# hayma' not found. Skipping...
# Processing Record 32 of Set 9 | afsin
# Processing Record 34 of Set 9 | lloydminster
# Processing Record 36 of Set 9 | calvinia
# Processing Record 38 of Set 9 | antonio enes
# Processing Record 40 of Set 9 | sinabang
# Processing Record 42 of Set 9 | kuanda
# Processing Record 44 of Set 9 | black forest
# Processing Record 46 of Set 9 | wamba
# Processing Record 48 of Set 9 | kalamb
# Processing Record 50 of Set 9 | kayar
# Processing Record 52 of Set 9 | aral
# Processing Record 54 of Set 9 | mananjary
# Processing Record 56 of Set 9 | tostado
# Processing Record 58 of Set 9 | gizo
# Processing Record 60 of Set 9 | selfoss
# Processing Record 62 of Set 9 | banda aceh
# Processing Record 64 of Set 9 | villa emilio carranza
# Processing Record 66 of Set 9 | lorengau
# Processing Record 68 of Set 9 | cajamar
# Processing Record 70 of Set 9 | carnarvon
# Processing Record 72 of Set 9 | beaufort west
# Processing Record 74 of Set 9 | tongchuanshi
# Processing Record 76 of Set 9 | cooper's town
# Processing Record 78 of Set 9 | rosarito
# Processing Record 80 of Set 9 | kavaratti
# Processing Record 82 of Set 9 | hami
# Processing Record 84 of Set 9 | santa elena de uairen
# Processing Record 86 of Set 9 | vieste
# Processing Record 88 of Set 9 | muroto-misakicho
# Processing Record 90 of Set 9 | phongsali
# Processing Record 92 of Set 9 | coracora
# Processing Record 94 of Set 9 | princeville
# Processing Record 96 of Set 9 | acatlan de osorio
# Processing Record 98 of Set 9 | hadibu
# Processing Record 0 of Set 10 | fyodorovka
# Processing Record 2 of Set 10 | nanpara
# Processing Record 4 of Set 10 | barceloneta
# Processing Record 6 of Set 10 | portland
# Processing Record 8 of Set 10 | bhimunipatnam
# Processing Record 10 of Set 10 | acarau
# Processing Record 12 of Set 10 | hirara
# Processing Record 14 of Set 10 | neiafu
# Processing Record 16 of Set 10 | jose pedro varela
# Processing Record 18 of Set 10 | narayanpet
# Processing Record 20 of Set 10 | tralee
# Processing Record 22 of Set 10 | griffith
# Processing Record 24 of Set 10 | ayacucho
# Processing Record 26 of Set 10 | oyama
# Processing Record 28 of Set 10 | placido de castro
# Processing Record 30 of Set 10 | nema
# Processing Record 32 of Set 10 | manggar
# Processing Record 34 of Set 10 | kenai
# Processing Record 36 of Set 10 | sijunjung
# Processing Record 38 of Set 10 | whitefish
# Processing Record 40 of Set 10 | dawei
# Processing Record 42 of Set 10 | nuku'alofa
# Processing Record 44 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | castillos
# Processing Record 48 of Set 10 | burunday
# Processing Record 50 of Set 10 | rio tuba
# Processing Record 52 of Set 10 | nabire
# Processing Record 54 of Set 10 | midvagur
# Processing Record 56 of Set 10 | raton
# Processing Record 58 of Set 10 | port saint john's
# Processing Record 60 of Set 10 | myitkyina
# Processing Record 62 of Set 10 | tanout
# Processing Record 64 of Set 10 | saint-leu
# Processing Record 66 of Set 10 | barntrup
# Processing Record 68 of Set 10 | sao joao da barra
# Processing Record 70 of Set 10 | vitoria do mearim
# Processing Record 72 of Set 10 | vila franca do campo
# Processing Record 74 of Set 10 | zhigalovo
# Processing Record 76 of Set 10 | susuman
# Processing Record 78 of Set 10 | novaya igirma
# Processing Record 80 of Set 10 | christchurch
# Processing Record 82 of Set 10 | turtas
# Processing Record 84 of Set 10 | chengde
# Processing Record 86 of Set 10 | el charco
# Processing Record 88 of Set 10 | thief river falls
# Processing Record 90 of Set 10 | ras gharib
# ras gharib not found. Skipping...
# Processing Record 92 of Set 10 | kruisfontein
# Processing Record 94 of Set 10 | praia
# Processing Record 96 of Set 10 | coquimbo
# Processing Record 98 of Set 10 | dar chioukh
# Processing Record 0 of Set 11 | cascais
# Processing Record 2 of Set 11 | jiazi
# Processing Record 4 of Set 11 | ust'-kulom
# Processing Record 6 of Set 11 | villa ojo de agua
# Processing Record 8 of Set 11 | labasa
# Processing Record 10 of Set 11 | ouesso
# Processing Record 12 of Set 11 | muzayri'
# muzayri' not found. Skipping...
# Processing Record 14 of Set 11 | turmalina
# Processing Record 16 of Set 11 | nantucket
# Processing Record 18 of Set 11 | egilsstadir
# Processing Record 20 of Set 11 | singkil
# Processing Record 22 of Set 11 | san juan
# Processing Record 24 of Set 11 | zeya
# Processing Record 26 of Set 11 | usogorsk
# Processing Record 28 of Set 11 | vuokatti
# Processing Record 30 of Set 11 | sao jose da coroa grande
# Processing Record 32 of Set 11 | laojunmiao
# Processing Record 34 of Set 11 | abalak
# Processing Record 36 of Set 11 | minot air force base
# Processing Record 38 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | sangkhla buri
# Processing Record 42 of Set 11 | nicoya
# Processing Record 44 of Set 11 | margate
# Processing Record 46 of Set 11 | fort st. john
# Processing Record 48 of Set 11 | mukalla
# Processing Record 50 of Set 11 | chom thong
# Processing Record 52 of Set 11 | north bend
# Processing Record 54 of Set 11 | saint helier
# Processing Record 56 of Set 11 | mariental
# Processing Record 58 of Set 11 | kathmandu
# Processing Record 60 of Set 11 | narok
# Processing Record 62 of Set 11 | lethem
# Processing Record 64 of Set 11 | abadan
# Processing Record 66 of Set 11 | port lincoln
# Processing Record 68 of Set 11 | novoishimskiy
# Processing Record 70 of Set 11 | saldanha
# Processing Record 72 of Set 11 | kapa'a
# Processing Record 74 of Set 11 | vila velha
# Processing Record 76 of Set 11 | barcelos
# Processing Record 78 of Set 11 | acapulco de juarez
# Processing Record 80 of Set 11 | dunay
# Processing Record 82 of Set 11 | forrest city
# Processing Record 84 of Set 11 | gamba
# Processing Record 86 of Set 11 | sanghar
# Processing Record 88 of Set 11 | pudasjarvi
# Processing Record 90 of Set 11 | marsabit
# Processing Record 92 of Set 11 | karpinsk
# Processing Record 94 of Set 11 | bel ombre
# Processing Record 96 of Set 11 | yangor
# yangor not found. Skipping...
# Processing Record 98 of Set 11 | tabou
# Processing Record 0 of Set 12 | izhmorskiy
# Processing Record 2 of Set 12 | grand falls-windsor
# Processing Record 4 of Set 12 | pointe michel
# Processing Record 6 of Set 12 | upata
# Processing Record 8 of Set 12 | tashtagol
# Processing Record 10 of Set 12 | galeana
# Processing Record 12 of Set 12 | sirte
# Processing Record 14 of Set 12 | manfalut
# Processing Record 16 of Set 12 | ipilan
# Processing Record 18 of Set 12 | platteville
# Processing Record 20 of Set 12 | ust'-ilimsk
# Processing Record 22 of Set 12 | newman
# Processing Record 24 of Set 12 | basco
# Processing Record 26 of Set 12 | novomichurinsk
# Processing Record 28 of Set 12 | cidade velha
# Processing Record 30 of Set 12 | kidatu
# Processing Record 32 of Set 12 | sisimiut
# Processing Record 34 of Set 12 | taro
# Processing Record 36 of Set 12 | kosong
# Processing Record 38 of Set 12 | sarlat-la-caneda
# Processing Record 40 of Set 12 | port isabel
# Processing Record 42 of Set 12 | minas de matahambre
# Processing Record 44 of Set 12 | aswan
# Processing Record 46 of Set 12 | pitimbu
# Processing Record 48 of Set 12 | namibe
# Processing Record 50 of Set 12 | vilyuysk
# Processing Record 52 of Set 12 | zhanaozen
# Processing Record 54 of Set 12 | buala
# Processing Record 56 of Set 12 | sosnovka
# Processing Record 58 of Set 12 | cafayate
# Processing Record 60 of Set 12 | palmer
# Processing Record 62 of Set 12 | nguigmi
# Processing Record 64 of Set 12 | kulia village
# kulia village not found. Skipping...
# Processing Record 66 of Set 12 | phalaborwa
# Processing Record 68 of Set 12 | maumere
# Processing Record 70 of Set 12 | guichon
# Processing Record 72 of Set 12 | dvurechensk
# Processing Record 74 of Set 12 | senahu
# Processing Record 76 of Set 12 | farkhor
# Processing Record 78 of Set 12 | suntar
# Processing Record 80 of Set 12 | kapuskasing
# Processing Record 82 of Set 12 | pacocha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# Display sample data
city_data_df.head()
# Out:
#                           City Country        Date      Lat       Lng  \
# 0                  vernouillet      FR  1736455908  48.7167    1.3667
# 1                     qaqortoq      GL  1736455909  60.7167  -46.0333
# 2                       badger      US  1736455911  64.8000 -147.5333
# 3                     waitangi      NZ  1736455912 -43.9535 -176.5597
# 4  edinburgh of the seven seas      SH  1736455913 -37.0676  -12.3116
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     37.17        85         100        7.87
# 1     13.60        69          16        7.56
# 2     15.71        86          20        4.61
# 3     54.82        79          94       15.01
# 4     64.17        91         100       10.94

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../WeatherPy_file", index=False)

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City Lat vs Max Temp.png")

# Show plot
plt.show()

print("This plot shows the relationship between the latitude of the city and the maximum temperature of the city. The plot shows that the temperature is higher near the equator and decreases as we move away from the equator.")
# Out:
# This plot shows the relationship between the latitude of the city and the maximum temperature of the city. The plot shows that the temperature is higher near the equator and decreases as we move away from the equator.

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City Lat vs Humidity.png")

# Show plot
plt.show()

print("This plot shows the relationship between the latitude of the city and the humidity of the city. The plot shows that the humidity is higher near the equator and decreases as we move away from the equator.")
# Out:
# This plot shows the relationship between the latitude of the city and the humidity of the city. The plot shows that the humidity is higher near the equator and decreases as we move away from the equator.

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City Lat vs Cloudiness.png")

# Show plot
plt.show()

print("This plot shows the relationship between the latitude of the city and the cloudiness of the city. The plot shows that the cloudiness is higher near the equator and decreases as we move away from the equator.")
# Out:
# This plot shows the relationship between the latitude of the city and the cloudiness of the city. The plot shows that the cloudiness is higher near the equator and decreases as we move away from the equator.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City Lat vs Wind Speed.png")

# Show plot
plt.show()

print("This plot shows the relationship between the latitude of the city and the wind speed of the city. The plot shows that the wind speed is higher near the equator and decreases as we move away from the equator.")
# Out:
# This plot shows the relationship between the latitude of the city and the wind speed of the city. The plot shows that the wind speed is higher near the equator and decreases as we move away from the equator.

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
northern_hemi_df.head()
# Out:
#               City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0      vernouillet      FR  1736455908  48.7167    1.3667     37.17        85
# 1         qaqortoq      GL  1736455909  60.7167  -46.0333     13.60        69
# 2           badger      US  1736455911  64.8000 -147.5333     15.71        86
# 5  sharm el-sheikh      EG  1736455914  27.8518   34.3050     62.74        48
# 6           bardai      NG  1736455915  11.6500    7.2333     64.26        24
#
#    Cloudiness  Wind Speed
# 0         100        7.87
# 1          16        7.56
# 2          20        4.61
# 5           0        4.61
# 6           2       10.02

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
southern_hemi_df.head()
# Out:
#                            City Country        Date      Lat       Lng  \
# 3                      waitangi      NZ  1736455912 -43.9535 -176.5597
# 4   edinburgh of the seven seas      SH  1736455913 -37.0676  -12.3116
# 8                    bredasdorp      ZA  1736455918 -34.5322   20.0403
# 14                 invercargill      NZ  1736455671 -46.4000  168.3500
# 15                    adamstown      PN  1736455927 -25.0660 -130.1015
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 3      54.82        79          94       15.01
# 4      64.17        91         100       10.94
# 8      67.62        81           5       15.01
# 14     56.01        91          91        1.99
# 15     76.95        81         100       24.16

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")

    plt.show()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plt.title("Northern Hemisphere - City Latitude vs Maximum Temperature")
plot_linear_regression(x_values, y_values, 'Max Temp', (0, 0))
# Out:
# The r-squared is: -0.8546051221652875

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plt.title("Southern Hemisphere - City Latitude vs Maximum Temperature")
plot_linear_regression(x_values, y_values, 'Max Temp', (-50, 90))
# Out:
# The r-squared is: 0.5338020402348506

# %% [markdown]
# **Comparison of Results**: City Latitude vs Max Temperature
#
# * _Northern Hemisphere_: It can be seen that with the linear regression analysis, there is a negative slope, indicating that maximum temperatures decrease as latitude values increase. This is overall consistent with the expectation that regions closer to the equator are warmer.
#
# * _Southern Hemisphere_: The analysis shows a postive slope, but since latitudes are negative, the interpretation remains that temperatures decrease as one moves further from the equator.
#
# Conclusion: The linear regression analyses for both hemispheres confirm that there is a significant linear relationship between latitude and maximum temperature. In both hemispheres, maximum temperatures tend to decrease as one moves away from the equator. This relationship is reflected in the negative slopes of the regression lines for both hemispheres. Understanding this relationship helps in predicting climatic conditions based on geographic location and can be useful for various applications in environmental science and urban planning.
#
# By performing these analyses, we can better understand the climatic patterns and how they are influenced by geographic factors such as latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plt.title("Northern Hemisphere - City Latitude vs Humidity")
plot_linear_regression(x_values, y_values, 'Humidity', (40, 10))
# Out:
# The r-squared is: 0.43218215790343745

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plt.title("Southern Hemisphere - City Latitude vs Humidity")
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 15))
# Out:
# The r-squared is: 0.3359653338299789

# %% [markdown]
# **Comparison of Results**: City Latitude vs Humidity
#
# * _Northern Hemisphere_: The linear regression analysis shows that a strong linear relationship. The slope indicates how humidity changes with latiude. The positive slope indicates that hudmidity increases as one moves away from the equator.
#
# * _Southern Hemisphere_: The analysis shows that is only a slight correlation between city latitude and humidity. Since the latitudes are negative, the interpretation remains that the slope indicates how humidity changes as one moves further from the equator.
#
# Conclusion: The linear regression analyses for both hemispheres provide insights into the relationship between latitude and humidity. The slopes of the regression lines indicate whether humidity tends to increase or decrease as one moves away from the equator. Understanding this relationship is important for predicting climatic conditions and can be useful for various applications in environmental science and urban planning.
#
# By examining the plots and the regression results, we can better understand how geographic factors such as latitude influence humidity levels in different parts of the world. This knowledge helps in making informed decisions related to climate and weather forecasting.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.title("Northern Hemisphere - City Latitude vs Cloudiness")
plot_linear_regression(x_values, y_values, 'Cloudiness', (40, 10))
# Out:
# The r-squared is: 0.229308396157611

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plt.title("Southern Hemisphere - City Latitude vs Cloudiness")
plot_linear_regression(x_values, y_values, 'Cloudiness', (-50, 60))
# Out:
# The r-squared is: 0.12395509635032374

# %% [markdown]
# **Comparison of Results**: City Latitude vs Cloudiness
#
# * _Northern Hemisphere_: The slope of the regression line indicates how cloudiness changes with latitude. A postive slope suggest increasing latitude as one moves further south from the equator, increases cloudiness.
#
# * _Southern Hemisphere_: Similarly, the slope of the regression line indicates how cloudiness changes with latitude. The postive slope suggests that increasing cloudiness increases with moving south and changes in latitude.
#
# Conclusion: The linear regression analyses for both hemispheres reveal that there is a linear relationship between latitude and cloudiness. The direction and magnitude of the slopes provide insights into how cloudiness varies with latitude in each hemisphere. Understanding these relationships helps in predicting climatic patterns and can be useful for weather forecasting and environmental planning.
#
# By comparing the results from both hemispheres, we can observe whether the trends in cloudiness with respect to latitude are consistent or if there are notable differences. This comparative analysis enhances our understanding of how geographic factors influence cloudiness globally.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plt.title("Northern Hemisphere - City Latitude vs Wind Speed")
plot_linear_regression(x_values, y_values, 'Wind Speed', (40, 25))
# Out:
# The r-squared is: 0.006416451521602062

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plt.title("Southern Hemisphere - City Latitude vs Wind Speed")
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# The r-squared is: -0.14139059367033796

# %% [markdown]
# **Comparison of Results**: City Latitude vs Wind Speed
#
# * _Northern Hemisphere_: Per the results, it can be infered that the slope of the regression line indicates how wind speed changes with latitude. However since the fitted line shows little to no movement, it can be said that there is very little correlation between latitude and wind speed.
#
# * _Southern Hemisphere_: The slope of the regression line indicates a negative slope, suggesting that wind speed decreases with increasing latitude.
#
# Conclusion: The linear regression analyses for both hemispheres reveal that there is a linear relationship between latitude and wind speed. The direction and magnitude of the slopes provide insights into how wind speed varies with latitude in each hemisphere. Understanding these relationships helps in predicting climatic patterns and can be useful for weather forecasting and environmental planning.
#
# By comparing the results from both hemispheres, we can observe whether the trends in wind speed with respect to latitude are consistent or if there are notable differences. This comparative analysis enhances our understanding of how geographic factors influence wind speed globally.

# %%
# Data was extracted from OpenWeatherMap API (2012—2025 OpenWeather; All Rights Reserved)
